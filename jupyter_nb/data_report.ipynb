# %%
import sqlite3
import pandas as pd
#conn = sqlite3.connect('../data/refined/IST-database.db')
df = pd.read_sql('SELECT * FROM my_table', conn)

print(df)
# Out:
#          caseid      sender target   startdate     terdate  defactoter  \
# 0     EU_CUB_03        1830     40  05.06.2003  23.06.2008  31.01.2005
# 1    OAS_CUB_62        3900     40  31.01.1962  03.06.2009
# 2    USA_CUB_03           2     40  09.09.2003  05.10.2015
# 3    USA_CUB_58           2     40  14.03.1958
# 4    EEC_HAI_91  1653, 1830     41  01.10.1991  16.10.1994
# ..          ...         ...    ...         ...         ...         ...
# 394  USA_FIJ_00           2    950  19.07.2000  30.09.2003
# 395  USA_FIJ_03           2    950  01.07.2003  30.12.2003
# 396  USA_FIJ_06           2    950  19.12.2006  29.05.2015
# 397  USA_FIJ_09           2    950  14.09.2009  10.09.2010
# 398  USA_WSM_03           2    990  01.07.2003  27.11.2006
#
#     ongoing gradual   expiry   review  ...                       outcome  \
# 0         0       0        0        0  ...           Sender capitulation
# 1         0       1        0        0  ...           Sender capitulation
# ...
