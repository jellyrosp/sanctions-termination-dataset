# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('../data/refined/IST-database.db')
df = pd.read_sql('SELECT * FROM my_table', conn)

print(df)
# Out:
#          caseid  sender  target   startdate     terdate  defactoter  ongoing  \
# 0        caseid  sender  target   startdate     terdate  defactoter  ongoing
# 1     EU_CUB_03    1830      40  05.06.2003  23.06.2008  31.01.2005        0
# 2    OAS_CUB_62    3900      40  31.01.1962  03.06.2009                    0
# 3    USA_CUB_03       2      40  09.09.2003  05.10.2015                    0
# 4    USA_CUB_58       2      40  14.03.1958                                1
# ..          ...     ...     ...         ...         ...         ...      ...
# 395  USA_FIJ_00       2     950  19.07.2000  30.09.2003                    0
# 396  USA_FIJ_03       2     950  01.07.2003  30.12.2003                    0
# 397  USA_FIJ_06       2     950  19.12.2006  29.05.2015                    0
# 398  USA_FIJ_09       2     950  14.09.2009  10.09.2010                    0
# 399  USA_WSM_03       2     990  01.07.2003  27.11.2006                    0
#
# ...
