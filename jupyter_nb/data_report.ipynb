# %%
import sqlite3
from pathlib import Path
import sys

BASE_DIR = Path().resolve().parent
sys.path.append(str(BASE_DIR / "src"))

from stats import descriptive as desc

con = sqlite3.connect(BASE_DIR / "data" / "IST-dataset.db")

# %%
#desc.get_cases_overview(con)

# %%
#desc.get_calculate_duration(con)

# %%
#desc.get_gradual_termination_distribution(con)

# %%
#desc.get_expiry_date_distribution(con)

# %%
#desc.get_review_distribution(con)

# %%
#desc.get_measure_distribution(con)

# %%
#desc.get_measure_distribution_per_sender(con)

# %%
#desc.get_measure_distribution_range(con)

# %%
#desc.get_goal_distribution(con)

# %%
#desc.get_goal_distribution_per_sender(con)

# %%
#desc.get_goal_distribution_range(con)

# %%
#desc.get_adapt_goal_distribution_per_sender(con)

# %%
#desc.get_target_salience_distribution_per_sender(con)

# %%
#desc.get_sender_salience_distribution_per_sender(con)

# %%
desc.get_requirement_distribution_per_sender(con)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 desc.get_requirement_distribution_per_sender(con)
#
# AttributeError: module 'stats.descriptive' has no attribute 'get_requirement_distribution_per_sender'

# %%
#desc.get_negotiations_distribution_per_sender(con)

# %%
#desc.get_inst_investment_distribution_per_sender(con)
# Out:
#                                                sender  inst_investment_yes  \
# 0                            united states of america                   56
# 1                                      united nations                   30
# 2                          union of the mediterranean                    0
# 3              southern african development community                    1
# 4   secretariat of the commission for east african...                    1
# 5                                  pan american union                    1
# 6                      organization for african unity                    5
# 7                               league of arab states                    1
# 8                                      european union                    2
# 9    european economic community - european community                    0
# 10          economic community of west african states                    4
# ...
