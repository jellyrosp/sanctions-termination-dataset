# %%
import sqlite3
from pathlib import Path
import sys

BASE_DIR = Path().resolve().parent
sys.path.append(str(BASE_DIR / "src"))

from stats.univariate import desc_analysis as desc, plots as plt

con = sqlite3.connect(BASE_DIR / "data" / "IST-dataset.db")
# Out:
#             Abs.  Rel(%)
# Clear      287.0    71.9
# Ambiguous  107.0    26.8
# Missing      5.0     1.3
# TOTAL      399.0   100.0

# %% [markdown]
# ## Univariate distributions
#
# Variables:
#
# - **expiry-date**: Boolean
# - **review**: Boolean
# - **requirement-termination**: Nominal, 2 categories
# - **outcome_type**: Nominal, 5 categories
# - **sender**: Nominal, 13 unique combinations
# - **duration**: Ordinal, 7 clusters
# - **gradual**: Boolean
# - **adaptation-goal**: Boolean
# - **negotiations**: Boolean
# - **multilateralism**: Boolean

# %%
print("\nFrequency distribution of sanction regimes by expity-date\n")
desc.get_expiry_distribution(con)
# Out:
# Frequency distribution of sanction regimes by expity-date
#                  Abs.  Rel(%)
# Stipulated       70.0    17.5
# Not stipulated  322.0    80.7
# Missing           7.0     1.8
# TOTAL           399.0   100.0

# %%
plt.plot_expiry_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/expiry_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by review\n")
desc.get_review_distribution(con)
# Out:
# Frequency distribution of sanction regimes by review
#                Abs.  Rel(%)
# Has review    140.0    35.1
# Lacks review  250.0    62.7
# Missing         9.0     2.3
# TOTAL         399.0   100.0

# %%
plt.plot_review_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/review_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by requirement termination\n")
desc.get_req_termination_distribution(con)
# Out:
# Frequency distribution of sanction regimes by requirement termination
#             Abs.  Rel(%)
# Clear      287.0    71.9
# Ambiguous  107.0    26.8
# Missing      5.0     1.3
# TOTAL      399.0   100.0

# %%
plt.plot_req_termination_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/req_termination_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by outcome\n")
desc.get_outcome_distribution(con)
# Out:
# Frequency distribution of sanction regimes by outcome
#                                                      Abs.  Rel(%)
# Missing                                             108.0    27.1
# Target complete acquiescence                        102.0    25.6
# Target partial acquiescence                          95.0    23.8
# Sender capitulation                                  48.0    12.0
# Stalemate                                            27.0     6.8
# Negotiated settlement & Target partial acquiesc...   10.0     2.5
# Negotiated settlement                                 4.0     1.0
# Negotiated settlement & Target complete acquies...    3.0     0.8
# Negotiated settlement & Sender capitulation           2.0     0.5
# TOTAL                                               399.0   100.0

# %%
plt.plot_outcome_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/outcome_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by sender\n")
desc.get_sender_distribution(con)
# Out:
# Frequency distribution of sanction regimes by sender
#            Abs.  Rel(%)
# USA       245.0    61.4
# EU         61.0    15.3
# UN         32.0     8.0
# EEC & EU   17.0     4.3
# OAU        14.0     3.5
# ECOWAS      9.0     2.3
# CommSec     7.0     1.8
# EEC         5.0     1.3
# OAS         3.0     0.8
# LAS         3.0     0.8
# EAC         1.0     0.3
# UM          1.0     0.3
# SADC        1.0     0.3
# TOTAL     399.0   100.0

# %%
plt.plot_sender_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/sender_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by duration interval (0-6m, 6m-1y, 1-2y, 2-5y, 5-10y, 10-20y, 20+y)\n")
desc.get_duration_distribution(con)
# Out:
# Frequency distribution of sanction regimes by duration interval (0-6m, 6m-1y, 1-2y, 2-5y, 5-10y, 10-20y, 20+y)
#          Abs.  Rel(%)
# 0–6m     53.0    13.3
# 6m–1y    38.0     9.5
# 1–2y     52.0    13.0
# 2–5y    121.0    30.3
# 5–10y    67.0    16.8
# 10–20y   43.0    10.8
# 20+y     25.0     6.3
# TOTAL   399.0   100.0

# %%
plt.plot_duration_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/duration_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by termination modality\n")
desc.get_gradual_distribution(con)
# Out:
# Frequency distribution of sanction regimes by termination modality
#               Abs.  Rel(%)
# Gradual      172.0    43.1
# Not Gradual  225.0    56.4
# Missing        2.0     0.5
# TOTAL        399.0   100.0

# %%
plt.plot_gradual_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/gradual_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by goal adaptation\n")
desc.get_adapt_goal_distribution(con)
# Out:
# Frequency distribution of sanction regimes by goal adaptation
#               Abs.  Rel(%)
# Not Adapted  349.0    87.5
# Adapted       47.0    11.8
# Missing        3.0     0.8
# TOTAL        399.0   100.0

# %%
plt.plot_adapt_goal_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/adapt_goal_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by negotiation presence\n")
desc.get_negotiation_distribution(con)
# Out:
# Frequency distribution of sanction regimes by negotiation presence
#                     Abs.  Rel(%)
# Has Negotiation    241.0    60.4
# Lacks Negotiation  156.0    39.1
# Missing              2.0     0.5
# TOTAL              399.0   100.0

# %%
plt.plot_negotiation_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/negotiation_distribution.svg

# %%
print("\nFrequency distribution of sanction regimes by multilateralism\n")
desc.get_multilateralism_distribution(con)
# Out:
# Frequency distribution of sanction regimes by multilateralism
#                Abs.  Rel(%)
# Unilateral    201.0    50.4
# Multilateral  198.0    49.6
# TOTAL         399.0   100.0

# %%
plt.plot_multilateralism_distribution(con)
# Out:
# Plot saved to: /home/ljutach/auri_projects/sanctions-termination-dataset/data_visual/univariate/multilateralism_distribution.svg
